# %% [markdown]
# Visualizing housing related data using Tableau. The data include:
# * Weekly earnings
# * Housing constructions
# * House prices
# * Housing price index
# * Office realestate index
# * Consumer price index

# %%
# import statements
import pandas as pd
import json

# %% [markdown]
# ### 1. Show the trend of house prices across Canada in the last 40 years

# %% [markdown]
# * After loading the housing_price_index table, the datatype Date attribute has to be changed from `string` to `date` to enable better flexibility and aggregation.
# * Since the Date attribute is at a monthly granularity, it is necessary to group the dates by year and then average the index values per the grouping. This ensures that the housing price index trend can be easily and readily spotted.
# * Since different measures are used to calculate the index value, it is neccessary to filter by related measures. This allows for meaningful interpretation of the resulting values. For this project, the house prices adjusted for consumer price inflation data will be utilized.

# %% [markdown]
# ![image.png](attachment:546d537d-f500-44f5-bda8-fba9ebc7177a.png)

# %% [markdown]
# ### 2. Compare the trend after 2005 with actual benchmark prices

# %% [markdown]
# * It is pertinent to note that the
# * To compare the trend of Canadian house prices by index values and benchmark prices, a line chart with dual axis will be utilized.
# * To get a clearer sense of the trends, the percentage change values using 2005 as the reference year is recalculated and plotted.
# * From the plots, it is clear that house prices are trending up, with the benchmark prices showing a faster increase. This is possibly due to the fact that the benchmark prices are nominal values and are not adjusted for inflation, like the house index values.

# %%
# Trends using raw values

# %% [markdown]
# ![image.png](attachment:77106352-7e90-415b-a84c-ed55ec99d5b4.png)

# %%
# Trends with percentage change showing clearer comparison

# %% [markdown]
# ![image.png](attachment:77ba5277-7f81-4525-aba2-fe0218c7c6fb.png)

# %% [markdown]
# ### 3. Compare the trend with the trend of office prices. Which one is getting more expensive faster?

# %% [markdown]
# * We can see that the real estate prices have also been trending up.
# * However, the pace of price increases for the real estate sector, while higher than the overall index, lags the price increase of the residential sector.

# %% [markdown]
# ![image.png](attachment:b3c98a39-237d-4c23-a7ff-45547f3147bc.png)

# %% [markdown]
# ### 4. Create a heatmap of Canada with current house prices for each available district.

# %% [markdown]
# * From the `real_estate_prices` file, there are four cities (districts) data provided across four different tables. The cities include Bancroft, Barrie, Brantford, and Calgary.
# * We first need to union these four tables together to create a combined table having a new attribute called `Table Name`.
# * With this done, we can then visualize the house price data across both years and cities using a heatmap.
# * For Bancoft, there seems to be a consistent increase in average house prices over the years, while Calgary has had a very stable but high average house price across the years. Barrie and Brancroft have shown more variablity, with relatively sharp increases in prices in recent years.

# %% [markdown]
# ![image.png](attachment:b00fcb74-1369-4bbb-958f-22c0e05298e3.png)

# %% [markdown]
# ### 5. Are the price differences between different districts increasing?

# %% [markdown]
# * This can still be inferred from the heatmap above. Remarkably, the average price differences between cities have been narrowing in recent years, as average prices in Bancroft and Brantford have caught up with the consistently high average house prices in Barrie and Calgary.
# * Alternatively, this can be answered more precisely using the bar chart below. Here, the overall average house price in all district is calculated per year, and then the average for each district is then subtracted from it. The plot of the differences show that the earlier observation is mostly true if you start observing the trend from 2014/2015.

# %% [markdown]
# ![image.png](attachment:9bdf701e-c517-4e37-8b62-f18a704cff3f.png)

# %% [markdown]
# ### 6. Compare the trend of house prices with earnings.

# %% [markdown]
# * The general trend for both average monthly housing prices and earnings is a steady increase with time.

# %% [markdown]
# ![image.png](attachment:1a6cef70-00ba-48f3-bc15-9c6f0f051147.png)

# %% [markdown]
# ### 7. Was housing more affordable in 2014 than it was in 2005?

# %% [markdown]
# * This question relates to housing affordability. By dividing the annual personal income by the average yearly house price, we get a relative measure of how much of a person's income is devoted to housing cost.
# * The interpretation is that in 2005, an individuals yearly income could pay for 18.5% of the cost of owning a home, but in 2014 that proportion dwindled to about 15%. Hence, housing has become less affordable, as home pric

# %% [markdown]
# ![image.png](attachment:60eb3e87-e087-40d4-ba35-bd02e5d5db4f.png)

# %% [markdown]
# ### 8. Did people spend more of their earnings in 2014 than they did in 2001?

# %% [markdown]
# * This is answered by adjusting earnings for inflation.
# * With the proportion of CPI compared to earnings expressed as a percentage, it is clear from the trend line that, on average, earnings have risen faster than inflation. Hence, consumers have actually spent a smaller proportion of their earnings on goods & services, on an inflation adjusted basis.

# %% [markdown]
# ![image.png](attachment:60263549-6be2-46d5-a8d4-9e0ec4f664d5.png)

# %% [markdown]
# ### 9. There were several economic crises in the world in the last 40 years, including these four: Black Monday (1987), Recession (early 1990s), dot com bubble (2000 - 2002), Financial crisis (2007 - 2009). Show the effect of these crises on:
# * Earnings
# * House prices
# * Office prices
# * House constructions
# * Consumer index

# %% [markdown]
# a. Earnings
#
# The effect of the economic crises on earnings seem muted, as yearly earnings maintained a relatively consistent upward trend
# throught out the periods of note.

# %% [markdown]
# ![image.png](attachment:b62481d1-62fe-4ca3-ba37-c9ef84000ec8.png)

# %% [markdown]
# b. House Prices and Office Prices
# There is insufficient data to evaluate the effect of the Dotcom bubble, since the housing benchmark price starts from 2005 and the office index from 2001. However, there is a marked downturn on both prices during the financial crises.

# %% [markdown]
# ![image.png](attachment:a4b869a5-acb4-45d5-8ff4-54782e6b04e0.png)

# %% [markdown]
# c. House Constructions

# %% [markdown]
# Consistent with the effect of global crises on the Canadian office and housing prices, housing construction seems to be particularly prone to this events. We can see marked reduction in the commencement of housing construction following the events of Black Monday, the Early 1990s Recession and the Financial Crises. However the DotCom Bubble seems to have hard to meaningful impact. This could be because it was more constrained to the technology sector and did not have a marked impact on the rest of the economy.

# %% [markdown]
# ![image.png](attachment:053ca2cb-612f-46cd-92b8-6e8bcf3b09ce.png)

# %% [markdown]
# d. Inflation Measures: Consumer Price Index (CPI)

# %% [markdown]
# Of the indicated notable events, only the financial crises had a meaningful impact on inflation, with
# price pressures reducing as the economy weakened.

# %% [markdown]
# ![image.png](attachment:107ccafe-284f-4607-b1bd-9abc202716a4.png)

# %% [markdown]
# ### 10. Plot consumer_index together with housing_price_index and fit the regression line between them. Can we predict consumer_index from the housing_price_index?

# %% [markdown]
# There is a statistically significant medium to strong correlation between the consumer price index and housing price index, which is quantified by an R-squared of 0.695. Hence, you can predict about 69.5% of the variation in the consumer index from the price index

# %% [markdown]
# ![image.png](attachment:7fe6c18f-093e-48c0-a8de-65bc7721ebfb.png)

# %% [markdown]
# ![image.png](attachment:cec827c0-d2c8-4f1f-b0ca-d44adb852cec.png)

# %% [markdown]
# ### 11. Try to find an interesting pattern, trend, outlier, etc. from the data used in the above questions

# %% [markdown]
# See Section 7 for additional trends related to cost of housing affordability
